# %%
import pandas as pd

# %%
data = pd.read_csv('raw_data/split_data2.csv', sep='\t', lineterminator='\n')
data.head(4)
# Out:
#    Unnamed: 0                  id        username           name  \
# 0       12078            46749727      bimbasecas     Bimba Bosé
# 1       12079          2302498848  aguirrekaren12          KAREN
# 2       12080  955504833154506753      FudgeLyons  Brandon Lyons
# 3       12081           346380340  brianjoliver31   Brian Oliver
#
#                                          description        location  \
# 0                                   Cardo Borriquero  Cádis, Espanha
# 1                                                22,        Houston
# 2  Software Engineer Currently @Microsoft\nSelf-t...             NYC
# 3  2nd year Doctorate of Physical Therapy student...     Madison, WI
#
#                  created_at  verified  protected  \
# 0  2009-06-12T21:11:11.000Z     False      False
# 1  2014-01-21T04:42:16.000Z     False      False
# 2  2018-01-22T18:17:59.000Z     False      False
# 3  2011-08-01T05:08:29.000Z     False      False
#
# ...
