# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from Twitter_bot_detection_713.data_prep import tweet_df_cleaner, user_df_cleaner

# %%
tweet_df = pd.read_parquet('../Twitter_bot_detection_713/data/tweets_df.parquet')
user_df = pd.read_csv('../raw_data/users_data.csv', sep='\t', lineterminator='\n')

# %%
print(tweet_df.shape)
print(user_df.shape)
# Out:
# (2353375, 12)
# (36234, 15)

# %%
tweet_df.head()
# Out:
#    possibly_sensitive lang                                        attachments  \
# 0               False   en  {'media_keys': ['3_1463160440935047191'], 'pol...
# 1               False   en  {'media_keys': ['3_1463115131844390914'], 'pol...
# 2               False   en  {'media_keys': ['3_1463069825182285824'], 'pol...
# 3               False   en  {'media_keys': ['3_1463024540825518082'], 'pol...
# 4               False   en  {'media_keys': ['3_1462979239485927428'], 'pol...
#
#             author_id                   id  \
# 0  787405734442958848  1463160444609351697
# 1  787405734442958848  1463115136424546310
# 2  787405734442958848  1463069828768403458
# 3  787405734442958848  1463024544902307840
# 4  787405734442958848  1462979242451365892
#
#                                                 text  \
# 0  Let's be the "Ill"\nin "Fillet" https://t.co/l...
# 1  You can't spell\n"Ambitious"\nwithout "Bit" ht...
# 2  We can put the\n"Cable" back in\n"Inexplicable...
# 3  We can't spell\n"Brute" without "Rut" https://...
# 4  We need "Abet"\nto spell "Diabetes" https://t....
#
#                                       public_metrics  \
# 0  {'like_count': 3, 'quote_count': 0, 'reply_cou...
# 1  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 2  {'like_count': 2, 'quote_count': 0, 'reply_cou...
# 3  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 4  {'like_count': 2, 'quote_count': 0, 'reply_cou...
#
#                  created_at entities in_reply_to_user_id referenced_tweets  \
# 0  2021-11-23T15:00:08.000Z     None                None              None
# 1  2021-11-23T12:00:06.000Z     None                None              None
# 2  2021-11-23T09:00:04.000Z     None                None              None
# 3  2021-11-23T06:00:07.000Z     None                None              None
# 4  2021-11-23T03:00:06.000Z     None                None              None
#
#   withheld
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
user_df.head()
# Out:
#    Unnamed: 0                  id         username                    name  \
# 0           0  787405734442958848  best_in_dumbest     The Best In Dumbest
# 1           1  796216118331310080     CJRubinPhoto                CJ Rubin
# 2           2  875949740503859204         SVGEGENT  🔥𝖙𝖍𝖊 𝖘𝖆𝖛𝖆𝖌𝖊 𝖌𝖊𝖓𝖙𝖑𝖊𝖒𝖆𝖓🔥
# 3           3  756119643622735875    TinkerVHECHK5         Danielle Tinker
# 4           4           464781334    JoleonLescott          Joleon Lescott
#
#                                          description                 location  \
# 0  Blame @xaiax, Inspired by @MakingInvisible, us...                      NaN
# 1  Photographing the American West since 1980. I ...           Estados Unidos
# 2  Part savage all gentleman                     ...                      NaN
# 3  Wife.Godmother.Friend.Feline Fanatic! Principa...           Birmingham, AL
# 4  England U21 Assistant Coach | @pumafootball Am...  England, United Kingdom
#
#                  created_at  verified  protected  \
# 0  2016-10-15T21:32:11.000Z     False      False
# 1  2016-11-09T05:01:30.000Z     False      False
# 2  2017-06-17T05:34:27.000Z     False      False
# 3  2016-07-21T13:32:25.000Z     False      False
# 4  2012-01-15T16:32:35.000Z      True      False
#
#                                    profile_image_url  followers_count  \
# 0  https://pbs.twimg.com/profile_images/787412182...             1848
# 1  https://pbs.twimg.com/profile_images/802329632...              812
# 2  https://pbs.twimg.com/profile_images/146262520...              182
# 3  https://pbs.twimg.com/profile_images/128488492...              657
# 4  https://pbs.twimg.com/profile_images/143779909...           739915
#
#    following_count  tweet_count  listed_count account_type
# 0                5        14542             0          bot
# 1              845          251             5        human
# 2              885         1288             2        human
# 3              747         1920             2        human
# 4              120         4459          1800        human

# %%
t_df = tweet_df_cleaner(tweet_df)
u_df = user_df_cleaner(user_df)

# %%
t_df
# Out:
#                    author_id                   id lang  \
# 0        1000029438233448448  1006523283645370368   it
# 1        1000029438233448448  1006561127600451595   it
# 2        1000029438233448448  1008732795357655040   it
# 3        1000029438233448448  1008984071031148544   it
# 4        1000029438233448448  1009725886579593216   it
# ...                      ...                  ...  ...
# 2353370   999977095106367488  1433726665553743872   it
# 2353371   999977095106367488  1435588625811611648   en
# 2353372   999977095106367488  1436375696033697835   en
# 2353373   999977095106367488  1445091030156648450   it
# 2353374   999977095106367488  1446584167379111937  und
#
#                                                       text  \
# 0        @luisellacost Li facciamo venire tutti a casa ...
# 1        @matteosalvinimi Siamo sulla strada giusta, ad...
# 2                                @matteosalvinimi Auguroni
# 3        @LegaSalvini Denunciate questo tizio per diffa...
# 4        @Pontifex_it @M_RSezione Dopo wojtyla siete il...
# ...                                                    ...
# 2353370  @stiIIxgolden madonna quanto ti posso capire, ...
# 2353371  song i wish someone wrote for me pt2: https://...
# 2353372  Behavioral research is built into every journe...
# 2353373                                 @tisaniina sì, sad
# 2353374                    &lt;3 u https://t.co/YpDV9SKeEA
#
#                        created_at              lag  possibly_sensitive  \
# 0       2018-06-12 13:07:05+00:00              NaT               False
# 1       2018-06-12 15:37:28+00:00  0 days 02:30:23               False
# 2       2018-06-18 15:26:54+00:00  5 days 23:49:26               False
# 3       2018-06-19 08:05:23+00:00  0 days 16:38:29               False
# 4       2018-06-21 09:13:05+00:00  2 days 01:07:42               False
# ...                           ...              ...                 ...
# 2353370 2021-09-03 09:40:49+00:00  4 days 21:37:39               False
# 2353371 2021-09-08 12:59:34+00:00  5 days 03:18:45               False
# 2353372 2021-09-10 17:07:07+00:00  2 days 04:07:33               False
# 2353373 2021-10-04 18:18:44+00:00 24 days 01:11:37               False
# 2353374 2021-10-08 21:11:56+00:00  4 days 02:53:12               False
#
#          referenced_tweets  reply_category  like_count  quote_count  \
# 0                     True  Reply_to_other           1            0
# 1                     True  Reply_to_other           0            0
# 2                     True  Reply_to_other           4            0
# 3                     True  Reply_to_other           0            0
# 4                     True  Reply_to_other           0            0
# ...                    ...             ...         ...          ...
# 2353370               True  Reply_to_other           0            0
# 2353371              False        No_reply           0            0
# 2353372              False        No_reply           0            0
# 2353373               True  Reply_to_other           1            0
# 2353374              False        No_reply           1            0
#
#          reply_count  retweet_count  n_mentions
# 0                  0              0           1
# 1                  0              0           1
# 2                  1              0           1
# 3                  0              0           1
# 4                  0              1           2
# ...              ...            ...         ...
# 2353370            1              0           1
# 2353371            0              0           0
# 2353372            0              0           0
# 2353373            0              0           1
# 2353374            0              0           0
#
# [2353375 rows x 14 columns]

# %%
u_df
# Out:
#                 author_id         username           user_display_name  \
# 0      787405734442958848  best_in_dumbest         The Best In Dumbest
# 1      796216118331310080     CJRubinPhoto                    CJ Rubin
# 2      875949740503859204         SVGEGENT      🔥𝖙𝖍𝖊 𝖘𝖆𝖛𝖆𝖌𝖊 𝖌𝖊𝖓𝖙𝖑𝖊𝖒𝖆𝖓🔥
# 3      756119643622735875    TinkerVHECHK5             Danielle Tinker
# 4               464781334    JoleonLescott              Joleon Lescott
# ...                   ...              ...                         ...
# 36229            63963107       butchsekab  Rosemary Pearman nee Bakes
# 36230          1064042478      Mathieu_Era              Tyrann Mathieu
# 36231          1089732602    SDalmaoficial                Sergio Dalma
# 36232           815529979      VinceYearly                   Mr. Vance
# 36233           434896892          zhemcom                     zhemcom
#
#                                                user_desc  \
# 0      Blame @xaiax, Inspired by @MakingInvisible, us...
# 1      Photographing the American West since 1980. I ...
# 2      Part savage all gentleman                     ...
# 3      Wife.Godmother.Friend.Feline Fanatic! Principa...
# 4      England U21 Assistant Coach | @pumafootball Am...
# ...                                                  ...
# 36229  Unemployed! Retail Assistant, Stocktaker, Dry ...
# 36230                                   FOLLOW ME ON IG.
# 36231  Bienvenid@s al Twitter Oficial de Sergio Dalma...
# 36232  Just a good guy wrapped up in a bad system.\nA...
# 36233                                              你好！中国
#
#                 user_created_at  user_verified  user_private  \
# 0     2016-10-15 21:32:11+00:00          False         False
# 1     2016-11-09 05:01:30+00:00          False         False
# 2     2017-06-17 05:34:27+00:00          False         False
# 3     2016-07-21 13:32:25+00:00          False         False
# 4     2012-01-15 16:32:35+00:00           True         False
# ...                         ...            ...           ...
# 36229 2009-08-08 13:11:15+00:00          False         False
# 36230 2013-01-05 21:35:37+00:00           True         False
# 36231 2013-01-14 18:05:54+00:00           True         False
# 36232 2012-09-10 16:12:02+00:00          False         False
# 36233 2011-12-12 12:59:28+00:00          False         False
#
#        user_followers_cnt  user_following_cnt  user_tweet_count  \
# 0                    1848                   5             14542
# 1                     812                 845               251
# 2                     182                 885              1288
# 3                     657                 747              1920
# 4                  739915                 120              4459
# ...                   ...                 ...               ...
# 36229                 152                1219               487
# 36230             1237990                 799             27326
# 36231               85615                 189              6640
# 36232                 137                 166              1040
# 36233                   3                   0              1521
#
#        user_list_count target
# 0                    0    bot
# 1                    5  human
# 2                    2  human
# 3                    2  human
# 4                 1800  human
# ...                ...    ...
# 36229                3  human
# 36230             1475  human
# 36231              270  human
# 36232                3  human
# 36233                0    bot
#
# [36234 rows x 12 columns]

# %%
target_join = u_df[['author_id', 'target']]
target_join
# Out:
#                 author_id target
# 0      787405734442958848    bot
# 1      796216118331310080  human
# 2      875949740503859204  human
# 3      756119643622735875  human
# 4               464781334  human
# ...                   ...    ...
# 36229            63963107  human
# 36230          1064042478  human
# 36231          1089732602  human
# 36232           815529979  human
# 36233           434896892    bot
#
# [36234 rows x 2 columns]

# %%
t_joined = t_df.merge(target_join, on='author_id', how='left')

# %%
t_joined['target'].value_counts()/len(t_joined)
# Out:
# human    0.840141
# bot      0.159859
# Name: target, dtype: float64

# %%
en_tweets = t_joined[t_joined['lang'] == 'en']

# %%
en_tweets['target'].value_counts()
# Out:
# human    1395617
# bot       217363
# Name: target, dtype: int64

# %%
u_df
# Out:
#                 author_id         username           user_display_name  \
# 0      787405734442958848  best_in_dumbest         The Best In Dumbest
# 1      796216118331310080     CJRubinPhoto                    CJ Rubin
# 2      875949740503859204         SVGEGENT      🔥𝖙𝖍𝖊 𝖘𝖆𝖛𝖆𝖌𝖊 𝖌𝖊𝖓𝖙𝖑𝖊𝖒𝖆𝖓🔥
# 3      756119643622735875    TinkerVHECHK5             Danielle Tinker
# 4               464781334    JoleonLescott              Joleon Lescott
# ...                   ...              ...                         ...
# 36229            63963107       butchsekab  Rosemary Pearman nee Bakes
# 36230          1064042478      Mathieu_Era              Tyrann Mathieu
# 36231          1089732602    SDalmaoficial                Sergio Dalma
# 36232           815529979      VinceYearly                   Mr. Vance
# 36233           434896892          zhemcom                     zhemcom
#
#                                                user_desc  \
# 0      Blame @xaiax, Inspired by @MakingInvisible, us...
# 1      Photographing the American West since 1980. I ...
# 2      Part savage all gentleman                     ...
# 3      Wife.Godmother.Friend.Feline Fanatic! Principa...
# 4      England U21 Assistant Coach | @pumafootball Am...
# ...                                                  ...
# 36229  Unemployed! Retail Assistant, Stocktaker, Dry ...
# 36230                                   FOLLOW ME ON IG.
# 36231  Bienvenid@s al Twitter Oficial de Sergio Dalma...
# 36232  Just a good guy wrapped up in a bad system.\nA...
# 36233                                              你好！中国
#
#                 user_created_at  user_verified  user_private  \
# 0     2016-10-15 21:32:11+00:00          False         False
# 1     2016-11-09 05:01:30+00:00          False         False
# 2     2017-06-17 05:34:27+00:00          False         False
# 3     2016-07-21 13:32:25+00:00          False         False
# 4     2012-01-15 16:32:35+00:00           True         False
# ...                         ...            ...           ...
# 36229 2009-08-08 13:11:15+00:00          False         False
# 36230 2013-01-05 21:35:37+00:00           True         False
# 36231 2013-01-14 18:05:54+00:00           True         False
# 36232 2012-09-10 16:12:02+00:00          False         False
# 36233 2011-12-12 12:59:28+00:00          False         False
#
#        user_followers_cnt  user_following_cnt  user_tweet_count  \
# 0                    1848                   5             14542
# 1                     812                 845               251
# 2                     182                 885              1288
# 3                     657                 747              1920
# 4                  739915                 120              4459
# ...                   ...                 ...               ...
# 36229                 152                1219               487
# 36230             1237990                 799             27326
# 36231               85615                 189              6640
# 36232                 137                 166              1040
# 36233                   3                   0              1521
#
#        user_list_count target
# 0                    0    bot
# 1                    5  human
# 2                    2  human
# 3                    2  human
# 4                 1800  human
# ...                ...    ...
# 36229                3  human
# 36230             1475  human
# 36231              270  human
# 36232                3  human
# 36233                0    bot
#
# [36234 rows x 12 columns]
