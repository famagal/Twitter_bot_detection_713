# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import requests
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from API_Twitter_bot_detection.api_get_data import *

# %%
user = user_data_request('best_in_dumbest')

# %%
tweets = tweet_data_request(user)
# Out:
# Could not fetch tweets from user.

# %%
headers = {
        'Authorization':
        'Bearer AAAAAAAAAAAAAAAAAAAAAGRNVwEAAAAA0khTD6u%2B1DoYpB%2BM%2B9OVcUNl5Pc%3DaKJmBoEn1exhbwQkVygK0hYysIU6kiCn1qGqymbHzgTeEzHqzD'
    }
user1 = user['id'][0]
url = f'https://api.twitter.com/2/users/{user1}/tweets?exclude=retweets&expansions=attachments.media_keys,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id&tweet.fields=attachments,created_at,in_reply_to_user_id,lang,possibly_sensitive,public_metrics,referenced_tweets,text&max_results=100'
response = requests.get(url, headers=headers).json()['data']
template = pd.read_parquet('../Twitter_bot_detection_713/data/template_twdf.parquet')
df = template.append(response)
df = df[df['author_id'] == user1]

# %%
df
# Out:
#     possibly_sensitive lang  \
# 0                False   en
# 0                False   en
# 1                False   en
# 2                False   en
# 3                False   en
# ..                 ...  ...
# 95               False   en
# 96               False   en
# 97               False   en
# 98               False   en
# 99               False   en
#
#                                           attachments           author_id  \
# 0   {'media_keys': ['3_1463160440935047191'], 'pol...  787405734442958848
# 0           {'media_keys': ['3_1466059538654588928']}  787405734442958848
# 1           {'media_keys': ['3_1466014237872906240']}  787405734442958848
# 2           {'media_keys': ['3_1465968933328998408']}  787405734442958848
# 3           {'media_keys': ['3_1465923640365518849']}  787405734442958848
# ..                                                ...                 ...
# 95          {'media_keys': ['3_1461756181471367171']}  787405734442958848
# 96          {'media_keys': ['3_1461710879154532352']}  787405734442958848
# 97          {'media_keys': ['3_1461665575139041284']}  787405734442958848
# 98          {'media_keys': ['3_1461620281064112128']}  787405734442958848
# 99          {'media_keys': ['3_1461574984791330822']}  787405734442958848
#
#                      id                                               text  \
# 0   1463160444609351697  Let's be the "Ill"\nin "Fillet" https://t.co/l...
# 0   1466059541951381507  We can't spell\n"Philistines"\nwithout "List" ...
# 1   1466014240716705797  We can't get the\n"Rim" out of\n"Patrimony" ht...
# 2   1465968936332103680  You need "Nap"\nto spell "Napalm" https://t.co...
# 3   1465923643226001411  Put the "Arm"\ninto "Warmup" https://t.co/kLB0...
# ..                  ...                                                ...
# 95  1461756184122179585  You can be the\n"Locate" in\n"Misallocated" ht...
# 96  1461710882577084425  Let's put the "Hind"\nback in "Shindig" https:...
# 97  1461665579178229763  We can't extract the\n"Abet" from\n"Alphabetiz...
# 98  1461620284348272640  Be the "Pose"\nin "Adipose" https://t.co/3fe9H...
# 99  1461574987484069895  We can't remove the\n"Aura" from\n"Restaurants...
#
#                                        public_metrics  \
# 0   {'like_count': 3, 'quote_count': 0, 'reply_cou...
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2   {'retweet_count': 5, 'reply_count': 0, 'like_c...
# 3   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ..                                                ...
# 95  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 96  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 97  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 98  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 99  {'retweet_count': 2, 'reply_count': 0, 'like_c...
#
#                   created_at entities in_reply_to_user_id referenced_tweets  \
# 0   2021-11-23T15:00:08.000Z     None                None              None
# 0   2021-12-01T15:00:07.000Z      NaN                 NaN               NaN
# 1   2021-12-01T12:00:06.000Z      NaN                 NaN               NaN
# 2   2021-12-01T09:00:05.000Z      NaN                 NaN               NaN
# 3   2021-12-01T06:00:06.000Z      NaN                 NaN               NaN
# ..                       ...      ...                 ...               ...
# 95  2021-11-19T18:00:07.000Z      NaN                 NaN               NaN
# 96  2021-11-19T15:00:06.000Z      NaN                 NaN               NaN
# 97  2021-11-19T12:00:05.000Z      NaN                 NaN               NaN
# 98  2021-11-19T09:00:06.000Z      NaN                 NaN               NaN
# 99  2021-11-19T06:00:06.000Z      NaN                 NaN               NaN
#
#    withheld
# 0      None
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ..      ...
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
#
# [101 rows x 12 columns]

# %%
tweets = tweet_data_request(user)
# Out:
# Could not fetch tweets from user.
