# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from Twitter_bot_detection_713.data_prep import get_final_tweet_data
from Twitter_bot_detection_713.preprocessing_text import apply_text_cleaning
# Out:
# 2021-12-02 16:43:05.373714: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-02 16:43:05.373774: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df_tweet = get_final_tweet_data(en=True)
df_tweet
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/gcsfs/core.py in _get_object(self, path)
#     451         try:
# --> 452             res = await self._call("GET", "b/{}/o/{}", bucket, key, json_out=True)
#     453         except OSError as e:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/gcsfs/core.py in _call(self, method, path, json_out, info_out, *args, **kwargs)
#     385
# --> 386         status, headers, info, contents = await self._request(
#     387             method, path, *args, **kwargs
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     220                 args, kw = fix(args, kw, sig)
# --> 221             return await caller(func, *(extras + args), **kw)
#     222     elif isgeneratorfunction(caller):
#
# ...

# %%
df_tweet_clean = apply_text_cleaning(df_tweet)

# %%
df_tweet_clean

# %%
text = df_tweet_clean.clean_text[13] + df_tweet_clean.clean_text[14] + df_tweet_clean.clean_text[300]

# %%
text
# Out:
# 'best pate everhave searching taste sincepcc great examplereach elected officialsay liyue'

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(tweet for tweet in df_tweet_clean.clean_text)
print ("There are {} words in the combination of all tweets.".format(len(text)))
# Out:
# There are 95075777 words in the combination of all tweets.

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Wordcloud bot

# %%
df_bot = df_tweet_clean[df_tweet_clean['target'] == 'bot']
df_bot
# Out:
#           author_id                   id lang  \
# 1116     1001667553   953924017861230593   en
# 1118     1001667553   971774363795165184   en
# 1119     1001667553   971774542128599040   en
# 1122     1001667553   971889284805484544   en
# 1124     1001667553   972287385047388161   en
# ...             ...                  ...  ...
# 2352722    99943864  1463070074126811137   en
# 2352738    99943864  1463198540625330177   en
# 2352740    99943864  1463201848559603724   en
# 2352773    99943864  1463233312344977411   en
# 2352774    99943864  1463235260230078464   en
#
#                                                       text  \
# 1116     hey man, all this can be your. Just see site i...
# 1118     Hello! What are you doing? I'm sad ... Look to...
# 1119     Love is a fire. But whether it is going to war...
# 1122     Hello! How are you? My new photo shoot in bio!...
# 1124     We are never so defensless against suffering a...
# ...

# %%
text_bot = " ".join(clean_text for clean_text in df_bot.clean_text)
print ("There are {} words in the combination of all tweets.".format(len(text_bot)))
# Out:
# There are 12595669 words in the combination of all tweets.

# %%
text_bot

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud_bot = WordCloud(stopwords=stopwords, background_color="white", max_words=500).generate(text_bot)

# %%
plt.imshow(wordcloud_bot, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Wordcloud human

# %%
df_human = df_tweet_clean[df_tweet_clean['target'] == 'human']
df_human
# Out:
#                   author_id                   id lang  \
# 13               1000197919  1261733558474829824   en
# 14               1000197919  1264695397588406272   en
# 15               1000197919  1271119064941752320   en
# 16               1000197919  1273846820133695488   en
# 17               1000197919  1275472007769976832   en
# ...                     ...                  ...  ...
# 2353366  999977095106367488  1426676881638793216   en
# 2353367  999977095106367488  1427777414088777728   en
# 2353369  999977095106367488  1431950553173659648   en
# 2353371  999977095106367488  1435588625811611648   en
# 2353372  999977095106367488  1436375696033697835   en
#
#                                                       text  \
# 13       @trekonomics Same here. Best pate ever....have...
# 14       PCC is a great example....reach out to your el...
# 15       both the theorem - and the conclusion. https:/...
# 16          @GeneralCattis they're learning from the best!
# ...

# %%
text_human = " ".join(clean_text for clean_text in df_human.clean_text)
print ("There are {} words in the combination of all tweets.".format(len(text_human)))
# Out:
# There are 82480107 words in the combination of all tweets.

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud_human = WordCloud(stopwords=stopwords, background_color="white", max_words=500).generate(text_human)

# %%
plt.imshow(wordcloud_human, interpolation='bilinear')
plt.axis("off")
plt.show()
