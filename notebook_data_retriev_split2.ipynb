# %%
import pandas as pd
import requests
import time

# %%
data = pd.read_parquet('test.parquet')

# %%
data
# Out:
#                      id lang  possibly_sensitive                created_at  \
# 0   1463160444609351697   en               False  2021-11-23T15:00:08.000Z
# 1   1463115136424546310   en               False  2021-11-23T12:00:06.000Z
# 2   1463069828768403458   en               False  2021-11-23T09:00:04.000Z
# 3   1463024544902307840   en               False  2021-11-23T06:00:07.000Z
# 4   1462979242451365892   en               False  2021-11-23T03:00:06.000Z
# ..                  ...  ...                 ...                       ...
# 95  1411338496019779588   en               False  2021-07-03T14:58:13.000Z
# 96  1411331128733143044   en               False  2021-07-03T14:28:57.000Z
# 97  1411275984641445888   en               False  2021-07-03T10:49:49.000Z
# 98  1411236343758442497   en               False  2021-07-03T08:12:18.000Z
# 99  1411236341682212864   en               False  2021-07-03T08:12:18.000Z
#
#                                                  text  \
# ...

# %%
data['lang'].nunique()
# Out:
# 8

# %%
 data['lang'].value_counts() / len(data['lang'].value_counts())
# Out:
# en     58.750
# und     2.875
# et      0.250
# it      0.125
# cy      0.125
# pl      0.125
# ro      0.125
# tl      0.125
# Name: lang, dtype: float64

# %%
df = pd.read_parquet('tweets_df_clemens.parquet')

# %%
df
# Out:
#    author_id                                     public_metrics  \
# 0   46749727  {'like_count': 167, 'quote_count': 4, 'reply_c...
# 1   46749727  {'like_count': 65, 'quote_count': 0, 'reply_co...
# 2   46749727  {'like_count': 226, 'quote_count': 13, 'reply_...
# 3   46749727  {'like_count': 215, 'quote_count': 7, 'reply_c...
# 4   46749727  {'like_count': 253, 'quote_count': 9, 'reply_c...
# ..       ...                                                ...
# 95  52568346  {'like_count': 2, 'quote_count': 0, 'reply_cou...
# 96  52568346  {'like_count': 1, 'quote_count': 0, 'reply_cou...
# 97  52568346  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 98  52568346  {'like_count': 1, 'quote_count': 0, 'reply_cou...
# 99  52568346  {'like_count': 0, 'quote_count': 0, 'reply_cou...
#
#                                                  text lang  \
# 0   Hoy es la gran noche de la #GalaSida #BorraelS...   es
# 1                             https://t.co/kqpnoUV8Eh  und
# ...

# %%
df['lang'].value_counts()
# Out:
# en     319322
# und     47019
# es      25895
# pt      12383
# ja       8442
# ar       8029
# it       7432
# in       7003
# tr       4738
# ko       3458
# fr       3451
# ru       2983
# tl       2349
# de       1984
# nl       1400
# zh        862
# hi        832
# th        775
# ht        680
# ca        579
# et        552
# pl        519
# sv        490
# da        305
# fi        302
# cy        281
# hu        246
# no        231
# lt        183
# eu        179
# ro        172
# vi        139
# is        125
# cs        110
# el        107
# sl         94
# lv         86
# ta         67
# ur         66
# or         64
# fa         61
# bn         51
# uk         43
# pa         36
# hy         26
# bg         18
# mr         14
# ne         12
# te          9
# ml          9
# iw          7
# ps          6
# sr          4
# kn          4
# ka          1
# km          1
# gu          1
# Name: lang, dtype: int64

# %%
df_2 = pd.read_parquet('tweets_df_2_clemens.parquet')

# %%
df_2
# Out:
#                   created_at                   id  \
# 0   2021-11-20T17:20:54.000Z  1462108702798921732
# 1   2021-10-14T21:02:42.000Z  1448756169539993601
# 2   2021-10-12T17:51:40.000Z  1447983320298569732
# 3   2021-09-29T10:58:20.000Z  1443168260015411203
# 4   2021-09-16T20:35:43.000Z  1438602521828904961
# ..                       ...                  ...
# 95  2021-08-28T01:04:54.000Z  1431422505374257154
# 96  2021-08-28T00:13:26.000Z  1431409551518044169
# 97  2021-08-27T23:06:09.000Z  1431392619804778503
# 98  2021-08-27T15:31:55.000Z  1431278307425898499
# 99  2021-08-26T21:36:25.000Z  1431007649139597312
#
#                                                  text lang  \
# 0   Turns out doing absolutely everything wasn’t e...   en
# 1        My heart is broken.💔 https://t.co/S5jn3u4iAN   en
# 2   If you live or are visiting in the area surrou...   en
# 3                           😔 https://t.co/oARSzhUopd  und
# 4   @VictoriaTheTech My daughter just told me abou...   en
# ...
